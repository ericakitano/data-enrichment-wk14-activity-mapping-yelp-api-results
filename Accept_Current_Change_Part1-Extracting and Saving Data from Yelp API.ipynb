# %% [markdown]
# # Part 1 - Extracting and Saving Data from Yelp API

# %% [markdown]
# ## Obective

# %% [markdown]
# - For this CodeAlong, we will be working with the Yelp API.
# - You will use the the Yelp API to search your home town for a cuisine type of your choice.
# - Next class, we will then use Plotly Express to create a map with the Mapbox API to visualize the results.

# %% [markdown]
# ## Tools You Will Use
# - Part 1:
#     - Yelp API:
#         - Getting Started:
#             - https://www.yelp.com/developers/documentation/v3/get_started
#
#     - `YelpAPI` python package
#         -  "YelpAPI": https://github.com/gfairchild/yelpapi
# - Part 2:
#
#     - Plotly Express: https://plotly.com/python/getting-started/
#         - With Mapbox API: https://www.mapbox.com/
#         - `px.scatter_mapbox` [Documentation](https://plotly.com/python/scattermapbox/):

# %% [markdown]
# ### Applying Code From
# - Efficient API Calls Lesson Link: https://login.codingdojo.com/m/376/12529/88078

# %%
# Standard Imports
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Additional Imports
# os - for saving and loading files
# json - to work with json files
# math - to round up results
# time - to add a short pause to not overwhelm the server
import os, json, math, time

# to make yelpapi calls
from yelpapi import YelpAPI

# progress bar from tqdm_notebook
from tqdm.notebook import tqdm_notebook

# %%
# !pip install yelpapi
# !pip install tqdm
# Out:
# Requirement already satisfied: yelpapi in /opt/homebrew/Caskroom/miniforge/base/envs/dojo-env/lib/python3.9/site-packages (2.5.0)
# Requirement already satisfied: requests in /opt/homebrew/Caskroom/miniforge/base/envs/dojo-env/lib/python3.9/site-packages (from yelpapi) (2.28.1)
# Requirement already satisfied: idna<4,>=2.5 in /opt/homebrew/Caskroom/miniforge/base/envs/dojo-env/lib/python3.9/site-packages (from requests->yelpapi) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /opt/homebrew/Caskroom/miniforge/base/envs/dojo-env/lib/python3.9/site-packages (from requests->yelpapi) (1.26.13)
# Requirement already satisfied: charset-normalizer<3,>=2 in /opt/homebrew/Caskroom/miniforge/base/envs/dojo-env/lib/python3.9/site-packages (from requests->yelpapi) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/homebrew/Caskroom/miniforge/base/envs/dojo-env/lib/python3.9/site-packages (from requests->yelpapi) (2022.9.24)

# %% [markdown]
# ## 1. Registering for Required APIs

# %% [markdown]
# - Yelp: https://www.yelp.com/developers/documentation/v3/get_started

# %% [markdown]
# > Check the official API documentation to know what arguments we can search for: https://www.yelp.com/developers/documentation/v3/business_search

# %% [markdown]
# ### Load Credentials and Create Yelp API Object

# %%
# Load API Credentials
# Load API Credentials
with open('/Users/ericakitano/.secret/yelp_api.json', 'r') as f:
    login = json.load(f)

# %%
login.keys()
# Out:
# dict_keys(['client-id', 'api-key'])

# %%
# Instantiate YelpAPI Variable
yelp = YelpAPI(login['api-key'], timeout_s = 5.0)

# %% [markdown]
# ### Define Search Terms and File Paths

# %%
# set our API call parameters and filename before the first call
location = 'Waikiki, HI'
term = 'acai'

# %%
location.split(',')[0]
# Out:
# 'Waikiki'

# %%
## Specify folder for saving data
FOLDER = 'Data/'

os.makedirs(FOLDER, exist_ok = True)


# Specifying JSON_FILE filename (can include a folder)
JSON_FILE = FOLDER+f"{location.split(',')[0]}-{term}.json"

# %%
JSON_FILE
# Out:
# 'Data/Waikiki-acai.json'

# %% [markdown]
# ### Check if Json File exists and Create it if it doesn't

# %%
os.path.isfile(JSON_FILE)
# Out:
# False

# %%
## Check if JSON_FILE exists
file_exists = os.path.isfile(JSON_FILE)
## If it does not exist: 
if file_exists == False:  
    ## CREATE ANY NEEDED FOLDERS
    # Get the Folder Name only
    folder = os.path.dirname(JSON_FILE)
    
    ## If JSON_FILE included a folder:
    if len(folder)>0:
        # create the folder
        os.makedirs(folder, exist_ok = True)
        
        
    ## INFORM USER AND SAVE EMPTY LIST
    print(f"[i] {JSON_FILE} not found. Saving empty list to file.")
    
    
    ## save the first page of results
    with open(JSON_FILE, 'w') as f:
          json.dump([], f)
        
## If it exists, inform user
else:
    print(f"[i] {JSON_FILE} already exists.")
# Out:
# [i] Data/Waikiki-acai.json not found. Saving empty list to file.

# %%
os.path.isfile(JSON_FILE)
# Out:
# True

# %%
## Check if JSON_FILE exists
file_exists = os.path.isfile(JSON_FILE)
## If it does not exist: 
if file_exists == False:  
    ## CREATE ANY NEEDED FOLDERS
    # Get the Folder Name only
    folder = os.path.dirname(JSON_FILE)
    
    ## If JSON_FILE included a folder:
    if len(folder)>0:
        # create the folder
        os.makedirs(folder, exist_ok = True)
        
        
    ## INFORM USER AND SAVE EMPTY LIST
    print(f"[i] {JSON_FILE} not found. Saving empty list to file.")
    
    
    ## save the first page of results
    with open(JSON_FILE, 'w') as f:
          json.dump([], f)
        
## If it exists, inform user
else:
    print(f"[i] {JSON_FILE} already exists.")
# Out:
# [i] Data/Waikiki-acai.json already exists.

# %% [markdown]
# ### Load JSON FIle and account for previous results

# %% [markdown]
# ### Make the first API call to get the first page of data

# %% [markdown]
# - We will use this first result to check:
#     - how many total results there are?
#     - Where is the actual data we want to save?
#     - how many results do we get at a time?

# %%
# use our yelp_api variable's search_query method to perform our API call
results = yelp.search_query(term = term, location = location)

# %%
type(results)
# Out:
# dict

# %%
len(results)
# Out:
# 3

# %%
results.keys()
# Out:
# dict_keys(['businesses', 'total', 'region'])

# %%
results['businesses']
# Out:
# [{'id': 'AVSOYqrPYsLo7c-XRDwobg',
#   'alias': 'the-sunrise-shack-honolulu',
#   'name': 'The Sunrise Shack',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/kGVUny4Oa838LYk4DZzX-w/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/the-sunrise-shack-honolulu?adjust_creative=L6aEZ7VCBeYnaQEYoR4t_A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=L6aEZ7VCBeYnaQEYoR4t_A',
#   'review_count': 784,
#   'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#    {'alias': 'juicebars', 'title': 'Juice Bars & Smoothies'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 21.277213128719804,
#    'longitude': -157.8275935854154},
#   'transactions': ['delivery'],
#   'price': '$$',
#   'location': {'address1': '2335 Kalakaua Ave',
#    'address2': '',
#    'address3': None,
#    'city': 'Honolulu',
#    'zip_code': '96815',
#    'country': 'US',
#    'state': 'HI',
#    'display_address': ['2335 Kalakaua Ave', 'Honolulu, HI 96815']},
#   'phone': '+18089266460',
#   'display_phone': '(808) 926-6460',
#   'distance': 243.57252567674212},
#  {'id': '3vsRGQGSVPec7kKBFGhowA',
#   'alias': 'alo-cafe-hawaii-honolulu-2',
#   'name': 'ALO Cafe Hawaii',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/_tn-bh_kYYsHl2aTPKi8Dw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/alo-cafe-hawaii-honolulu-2?adjust_creative=L6aEZ7VCBeYnaQEYoR4t_A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=L6aEZ7VCBeYnaQEYoR4t_A',
#   'review_count': 98,
#   'categories': [{'alias': 'juicebars', 'title': 'Juice Bars & Smoothies'},
#    {'alias': 'acaibowls', 'title': 'Acai Bowls'},
#    {'alias': 'vegan', 'title': 'Vegan'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 21.27713, 'longitude': -157.82433},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$$',
#   'location': {'address1': '159 Kaiulani Ave',
#    'address2': 'Ste 105',
#    'address3': '',
#    'city': 'Honolulu',
#    'zip_code': '96815',
#    'country': 'US',
#    'state': 'HI',
#    'display_address': ['159 Kaiulani Ave', 'Ste 105', 'Honolulu, HI 96815']},
#   'phone': '+18087797887',
#   'display_phone': '(808) 779-7887',
#   'distance': 505.7440941329483},
#  {'id': 'QMPFWhM_kMIMSSBQf48-Gg',
#   'alias': 'waffle-and-berry-honolulu',
#   'name': 'Waffle and Berry',
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/6VpIBTpWDBl7In0jAzXj6A/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/waffle-and-berry-honolulu?adjust_creative=L6aEZ7VCBeYnaQEYoR4t_A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=L6aEZ7VCBeYnaQEYoR4t_A',
#   'review_count': 675,
#   'categories': [{'alias': 'waffles', 'title': 'Waffles'},
#    {'alias': 'acaibowls', 'title': 'Acai Bowls'},
#    {'alias': 'coffee', 'title': 'Coffee & Tea'}],
#   'rating': 5.0,
#   'coordinates': {'latitude': 21.28594, 'longitude': -157.83275},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$$',
#   'location': {'address1': '1958 Kalakaua Ave',
#    'address2': 'Fl 2',
#    'address3': '',
#    'city': 'Honolulu',
#    'zip_code': '96815',
#    'country': 'US',
#    'state': 'HI',
#    'display_address': ['1958 Kalakaua Ave', 'Fl 2', 'Honolulu, HI 96815']},
#   'phone': '+18082068272',
#   'display_phone': '(808) 206-8272',
#   'distance': 1256.0617399727369},
#  {'id': 'FhShWwhWNm4j6yMjyF0MCw',
#   'alias': 'banán-waikiki-beach-shack-honolulu',
#   'name': 'Banán - Waikiki Beach Shack',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/HBcgiP0a_vkEo_YJ-RYuFA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/ban%C3%A1n-waikiki-beach-shack-honolulu?adjust_creative=L6aEZ7VCBeYnaQEYoR4t_A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=L6aEZ7VCBeYnaQEYoR4t_A',
#   'review_count': 518,
#   'categories': [{'alias': 'vegan', 'title': 'Vegan'},
#    {'alias': 'icecream', 'title': 'Ice Cream & Frozen Yogurt'},
#    {'alias': 'acaibowls', 'title': 'Acai Bowls'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 21.2772821247839,
#    'longitude': -157.827768717774},
#   'transactions': [],
#   'price': '$',
#   'location': {'address1': '2301 Kalakaua Ave',
#    'address2': '',
#    'address3': None,
#    'city': 'Honolulu',
#    'zip_code': '96815',
#    'country': 'US',
#    'state': 'HI',
#    'display_address': ['2301 Kalakaua Ave', 'Honolulu, HI 96815']},
#   'phone': '+18082001640',
#   'display_phone': '(808) 200-1640',
#   'distance': 242.2946621085445},
#  {'id': 'vZ6iGKsU7zX8MT5rwNJeZw',
#   'alias': 'tropical-tribe-honolulu',
#   'name': 'Tropical Tribe',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/e7Y1Qu2QSU3856atOud8ow/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/tropical-tribe-honolulu?adjust_creative=L6aEZ7VCBeYnaQEYoR4t_A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=L6aEZ7VCBeYnaQEYoR4t_A',
#   'review_count': 592,
#   'categories': [{'alias': 'acaibowls', 'title': 'Acai Bowls'},
#    {'alias': 'coffee', 'title': 'Coffee & Tea'},
#    {'alias': 'cafes', 'title': 'Cafes'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 21.28557897099554, 'longitude': -157.838434},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$$',
#   'location': {'address1': '1778 Ala Moana Blvd',
#    'address2': 'Ste 101',
#    'address3': '',
#    'city': 'Honolulu',
#    'zip_code': '96815',
#    'country': 'US',
#    'state': 'HI',
#    'display_address': ['1778 Ala Moana Blvd',
#     'Ste 101',
#     'Honolulu, HI 96815']},
#   'phone': '+18083668226',
#   'display_phone': '(808) 366-8226',
#   'distance': 1522.4729813228491},
#  {'id': 'vFz6Nwo0LgpbJcU9St-uPA',
#   'alias': 'da-cove-health-bar-and-cafe-honolulu-4',
#   'name': 'Da Cove Health Bar & Cafe',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/aNlP2wHfgFUSpP25A4Hb3w/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/da-cove-health-bar-and-cafe-honolulu-4?adjust_creative=L6aEZ7VCBeYnaQEYoR4t_A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=L6aEZ7VCBeYnaQEYoR4t_A',
#   'review_count': 1295,
#   'categories': [{'alias': 'juicebars', 'title': 'Juice Bars & Smoothies'},
#    {'alias': 'hawaiian', 'title': 'Hawaiian'},
#    {'alias': 'acaibowls', 'title': 'Acai Bowls'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 21.26878, 'longitude': -157.8136199},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$$',
#   'location': {'address1': '3045 Monsarrat Ave',
#    'address2': 'Ste 5',
#    'address3': '',
#    'city': 'Honolulu',
#    'zip_code': '96815',
#    'country': 'US',
#    'state': 'HI',
#    'display_address': ['3045 Monsarrat Ave', 'Ste 5', 'Honolulu, HI 96815']},
#   'phone': '+18087328744',
#   'display_phone': '(808) 732-8744',
#   'distance': 1718.0028184159814},
#  {'id': 'kg9DW8QwQ6NEorFdUSUhgA',
#   'alias': 'nalu-health-bar-and-cafe-urban-honolulu',
#   'name': 'Nalu Health Bar & Cafe',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/tn-UW0ZRdhKFTTy7DrBmDQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/nalu-health-bar-and-cafe-urban-honolulu?adjust_creative=L6aEZ7VCBeYnaQEYoR4t_A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=L6aEZ7VCBeYnaQEYoR4t_A',
#   'review_count': 10,
#   'categories': [{'alias': 'juicebars', 'title': 'Juice Bars & Smoothies'},
#    {'alias': 'acaibowls', 'title': 'Acai Bowls'},
#    {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 21.279401, 'longitude': -157.831178},
#   'transactions': [],
#   'location': {'address1': '226 Lewers St',
#    'address2': None,
#    'address3': '',
#    'city': 'Urban Honolulu',
#    'zip_code': '96815',
#    'country': 'US',
#    'state': 'HI',
#    'display_address': ['226 Lewers St', 'Urban Honolulu, HI 96815']},
#   'phone': '+18084254710',
#   'display_phone': '(808) 425-4710',
#   'distance': 530.1771598853006},
#  {'id': 'iGIjmLHJAiwUP-oHpWP-Sw',
#   'alias': 'aloh-health-bar-and-cafe-honolulu-2',
#   'name': 'Aloh Health Bar & Cafe',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/KuUnIWIKkCQ3ucgKoCtYnQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/aloh-health-bar-and-cafe-honolulu-2?adjust_creative=L6aEZ7VCBeYnaQEYoR4t_A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=L6aEZ7VCBeYnaQEYoR4t_A',
#   'review_count': 82,
#   'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#    {'alias': 'acaibowls', 'title': 'Acai Bowls'},
#    {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 21.280353794831946, 'longitude': -157.8266827},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$$',
#   'location': {'address1': '407 Seaside Ave',
#    'address2': None,
#    'address3': '',
#    'city': 'Honolulu',
#    'zip_code': '96815',
#    'country': 'US',
#    'state': 'HI',
#    'display_address': ['407 Seaside Ave', 'Honolulu, HI 96815']},
#   'phone': '+18085488116',
#   'display_phone': '(808) 548-8116',
#   'distance': 601.0924468422764},
#  {'id': 'oqnyvvSvWSNICv4QhzHyQg',
#   'alias': 'island-vintage-shave-ice-honolulu-7',
#   'name': 'Island Vintage Shave Ice',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/3frxsXKoJJrMRSc2bvXH1Q/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/island-vintage-shave-ice-honolulu-7?adjust_creative=L6aEZ7VCBeYnaQEYoR4t_A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=L6aEZ7VCBeYnaQEYoR4t_A',
#   'review_count': 99,
#   'categories': [{'alias': 'shavedice', 'title': 'Shaved Ice'},
#    {'alias': 'acaibowls', 'title': 'Acai Bowls'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 21.272783224863293,
#    'longitude': -157.82298618834332},
#   'transactions': [],
#   'price': '$$',
#   'location': {'address1': '2552 Kalakaua Ave',
#    'address2': 'Unit K100D & K100E',
#    'address3': None,
#    'city': 'Honolulu',
#    'zip_code': '96815',
#    'country': 'US',
#    'state': 'HI',
#    'display_address': ['2552 Kalakaua Ave',
#     'Unit K100D & K100E',
#     'Honolulu, HI 96815']},
#   'phone': '',
#   'display_phone': '',
#   'distance': 657.6453498470217},
#  {'id': 'tUDgSvk3bdNV_UJJ-yf7XQ',
#   'alias': 'aloha-bowls-and-tea-honolulu',
#   'name': 'Aloha Bowls and Tea',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/e_k8BmnK79LaIMfzSpcqTg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/aloha-bowls-and-tea-honolulu?adjust_creative=L6aEZ7VCBeYnaQEYoR4t_A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=L6aEZ7VCBeYnaQEYoR4t_A',
#   'review_count': 48,
#   'categories': [{'alias': 'acaibowls', 'title': 'Acai Bowls'},
#    {'alias': 'poke', 'title': 'Poke'},
#    {'alias': 'hawaiian', 'title': 'Hawaiian'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 21.28298862765927,
#    'longitude': -157.83612623949188},
#   'transactions': [],
#   'price': '$$',
#   'location': {'address1': '2005 Kalia Rd',
#    'address2': '',
#    'address3': 'Hilton Hawaiian Village',
#    'city': 'Honolulu',
#    'zip_code': '96815',
#    'country': 'US',
#    'state': 'HI',
#    'display_address': ['2005 Kalia Rd',
#     'Hilton Hawaiian Village',
#     'Honolulu, HI 96815']},
#   'phone': '+18088077733',
#   'display_phone': '(808) 807-7733',
#   'distance': 1148.3265725864958},
#  {'id': 'n5oK86I5tdZCBSR5vxw38A',
#   'alias': 'hawaiian-aroma-caffe-ohana-east-honolulu',
#   'name': 'Hawaiian Aroma Caffe - Ohana East',
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/V4cb0rgdtZzFAcNn1cZDBA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/hawaiian-aroma-caffe-ohana-east-honolulu?adjust_creative=L6aEZ7VCBeYnaQEYoR4t_A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=L6aEZ7VCBeYnaQEYoR4t_A',
#   'review_count': 281,
#   'categories': [{'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#    {'alias': 'coffee', 'title': 'Coffee & Tea'},
#    {'alias': 'acaibowls', 'title': 'Acai Bowls'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 21.27771853881159,
#    'longitude': -157.82478980861706},
#   'transactions': ['delivery'],
#   'price': '$$',
#   'location': {'address1': '150 Kaiulani Ave',
#    'address2': None,
#    'address3': None,
#    'city': 'Honolulu',
#    'zip_code': '96815',
#    'country': 'US',
#    'state': 'HI',
#    'display_address': ['150 Kaiulani Ave', 'Honolulu, HI 96815']},
#   'phone': '+18082562602',
#   'display_phone': '(808) 256-2602',
#   'distance': 489.23389718665874},
#  {'id': 'wX8nkQf0zGfYI6LaIuYqvQ',
#   'alias': 'tropical-tribe-honolulu-4',
#   'name': 'Tropical Tribe',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/G75exrIPY1R80oJsvByO3Q/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/tropical-tribe-honolulu-4?adjust_creative=L6aEZ7VCBeYnaQEYoR4t_A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=L6aEZ7VCBeYnaQEYoR4t_A',
#   'review_count': 27,
#   'categories': [{'alias': 'acaibowls', 'title': 'Acai Bowls'},
#    {'alias': 'coffee', 'title': 'Coffee & Tea'},
#    {'alias': 'juicebars', 'title': 'Juice Bars & Smoothies'}],
#   'rating': 5.0,
#   'coordinates': {'latitude': 21.278066211341383,
#    'longitude': -157.8334924846517},
#   'transactions': [],
#   'location': {'address1': '2161 Kalia rd.',
#    'address2': 'Ste 110',
#    'address3': '',
#    'city': 'Honolulu',
#    'zip_code': '96815',
#    'country': 'US',
#    'state': 'HI',
#    'display_address': ['2161 Kalia rd.', 'Ste 110', 'Honolulu, HI 96815']},
#   'phone': '+18087447079',
#   'display_phone': '(808) 744-7079',
#   'distance': 581.5590534641811},
#  {'id': 'GRvf-c-_ALRvhzXIvgD_tA',
#   'alias': 'tucker-and-bevvy-honolulu-5',
#   'name': 'Tucker & Bevvy',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/3u6koCVEQdQH8Xj6QOFjDA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/tucker-and-bevvy-honolulu-5?adjust_creative=L6aEZ7VCBeYnaQEYoR4t_A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=L6aEZ7VCBeYnaQEYoR4t_A',
#   'review_count': 575,
#   'categories': [{'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#    {'alias': 'sandwiches', 'title': 'Sandwiches'},
#    {'alias': 'juicebars', 'title': 'Juice Bars & Smoothies'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 21.27176916049238,
#    'longitude': -157.8223953024108},
#   'transactions': ['delivery'],
#   'price': '$$',
#   'location': {'address1': '2586 Kalakaua Ave',
#    'address2': '',
#    'address3': '',
#    'city': 'Honolulu',
#    'zip_code': '96815',
#    'country': 'US',
#    'state': 'HI',
#    'display_address': ['2586 Kalakaua Ave', 'Honolulu, HI 96815']},
#   'phone': '+18089220099',
#   'display_phone': '(808) 922-0099',
#   'distance': 764.7762956537241},
#  {'id': 'xNRyrUw1-6OyVQ44wKV-Og',
#   'alias': 'coffee-shop-831-honolulu',
#   'name': 'Coffee Shop 831',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/OCl2MnsAypXz5WDd4a_sdQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/coffee-shop-831-honolulu?adjust_creative=L6aEZ7VCBeYnaQEYoR4t_A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=L6aEZ7VCBeYnaQEYoR4t_A',
#   'review_count': 352,
#   'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#    {'alias': 'juicebars', 'title': 'Juice Bars & Smoothies'},
#    {'alias': 'acaibowls', 'title': 'Acai Bowls'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 21.2793199, 'longitude': -157.82505},
#   'transactions': ['delivery'],
#   'price': '$$',
#   'location': {'address1': '411 Nahua St',
#    'address2': '',
#    'address3': '',
#    'city': 'Honolulu',
#    'zip_code': '96815',
#    'country': 'US',
#    'state': 'HI',
#    'display_address': ['411 Nahua St', 'Honolulu, HI 96815']},
#   'phone': '+18088539888',
#   'display_phone': '(808) 853-9888',
#   'distance': 573.1593122260566},
#  {'id': 'RiwA77HKyZW1geZh2BJtgQ',
#   'alias': 'big-wave-dave-surf-and-coffee-honolulu-7',
#   'name': 'Big Wave Dave Surf & Coffee',
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/8AS_BzoLsnSp05ahvweG0A/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/big-wave-dave-surf-and-coffee-honolulu-7?adjust_creative=L6aEZ7VCBeYnaQEYoR4t_A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=L6aEZ7VCBeYnaQEYoR4t_A',
#   'review_count': 169,
#   'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#    {'alias': 'cafes', 'title': 'Cafes'},
#    {'alias': 'acaibowls', 'title': 'Acai Bowls'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 21.278767, 'longitude': -157.831514},
#   'transactions': ['delivery'],
#   'location': {'address1': '226 Lewers St',
#    'address2': 'Ste 154',
#    'address3': '',
#    'city': 'Honolulu',
#    'zip_code': '96815',
#    'country': 'US',
#    'state': 'HI',
#    'display_address': ['226 Lewers St', 'Ste 154', 'Honolulu, HI 96815']},
#   'phone': '+18083864872',
#   'display_phone': '(808) 386-4872',
#   'distance': 481.7152082724403},
#  {'id': 'lSuf6g0V6MmFe69ZxRRTrA',
#   'alias': 'kai-fresh-urban-honolulu',
#   'name': 'Kai Fresh',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/7ToiVay9t0MBx-1ewvci1Q/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/kai-fresh-urban-honolulu?adjust_creative=L6aEZ7VCBeYnaQEYoR4t_A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=L6aEZ7VCBeYnaQEYoR4t_A',
#   'review_count': 41,
#   'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#    {'alias': 'juicebars', 'title': 'Juice Bars & Smoothies'},
#    {'alias': 'acaibowls', 'title': 'Acai Bowls'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 21.27743, 'longitude': -157.82579},
#   'transactions': [],
#   'price': '$$',
#   'location': {'address1': '120 Kaiulani Ave',
#    'address2': None,
#    'address3': '',
#    'city': 'Urban Honolulu',
#    'zip_code': '96815',
#    'country': 'US',
#    'state': 'HI',
#    'display_address': ['120 Kaiulani Ave', 'Urban Honolulu, HI 96815']},
#   'phone': '',
#   'display_phone': '',
#   'distance': 418.4258834966523},
#  {'id': '3ZK5K9oMS5CTHBni0G9ieA',
#   'alias': 'the-sunrise-shack-honolulu-2',
#   'name': 'The Sunrise Shack',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/BEG9Tyt5Vn0Ssu3kQTQ5lA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/the-sunrise-shack-honolulu-2?adjust_creative=L6aEZ7VCBeYnaQEYoR4t_A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=L6aEZ7VCBeYnaQEYoR4t_A',
#   'review_count': 75,
#   'categories': [{'alias': 'juicebars', 'title': 'Juice Bars & Smoothies'},
#    {'alias': 'coffee', 'title': 'Coffee & Tea'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 21.29053, 'longitude': -157.84358},
#   'transactions': [],
#   'location': {'address1': '1450 Ala Moana Blvd',
#    'address2': '',
#    'address3': None,
#    'city': 'Honolulu',
#    'zip_code': '96814',
#    'country': 'US',
#    'state': 'HI',
#    'display_address': ['1450 Ala Moana Blvd', 'Honolulu, HI 96814']},
#   'phone': '+18082072604',
#   'display_phone': '(808) 207-2604',
#   'distance': 2288.268758977366},
#  {'id': 'n4hw4xPYXfcItEQD57UevA',
#   'alias': 'tucker-and-bevvy-honolulu-4',
#   'name': 'Tucker & Bevvy',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/3oBQVwmKmzVKI5Bo07LkAw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/tucker-and-bevvy-honolulu-4?adjust_creative=L6aEZ7VCBeYnaQEYoR4t_A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=L6aEZ7VCBeYnaQEYoR4t_A',
#   'review_count': 76,
#   'categories': [{'alias': 'juicebars', 'title': 'Juice Bars & Smoothies'},
#    {'alias': 'sandwiches', 'title': 'Sandwiches'},
#    {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 21.2761299, 'longitude': -157.82543},
#   'transactions': ['delivery'],
#   'location': {'address1': '2424 Kalakaua Ave',
#    'address2': '',
#    'address3': '',
#    'city': 'Honolulu',
#    'zip_code': '96815',
#    'country': 'US',
#    'state': 'HI',
#    'display_address': ['2424 Kalakaua Ave', 'Honolulu, HI 96815']},
#   'phone': '+18089222088',
#   'display_phone': '(808) 922-2088',
#   'distance': 360.60269291632187},
#  {'id': 'c5AkizffmwCSfUo2gd5Hxg',
#   'alias': 'hiking-hawaii-cafe-honolulu-3',
#   'name': 'Hiking Hawaii Cafe',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/1GOFwqROqn0YhDKkjyD5Wg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/hiking-hawaii-cafe-honolulu-3?adjust_creative=L6aEZ7VCBeYnaQEYoR4t_A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=L6aEZ7VCBeYnaQEYoR4t_A',
#   'review_count': 849,
#   'categories': [{'alias': 'cafes', 'title': 'Cafes'},
#    {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#    {'alias': 'juicebars', 'title': 'Juice Bars & Smoothies'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 21.28601, 'longitude': -157.83429},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$$',
#   'location': {'address1': '1956 Ala Moana Blvd',
#    'address2': '',
#    'address3': '',
#    'city': 'Honolulu',
#    'zip_code': '96815',
#    'country': 'US',
#    'state': 'HI',
#    'display_address': ['1956 Ala Moana Blvd', 'Honolulu, HI 96815']},
#   'phone': '+18084451717',
#   'display_phone': '(808) 445-1717',
#   'distance': 1309.5268701442315},
#  {'id': 'w7z7ucVr_XOCLyK-zgb9bQ',
#   'alias': 'hawaiian-aroma-caffe-the-ilikai-honolulu',
#   'name': 'Hawaiian Aroma Caffe - The Ilikai',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/OwnLS9bpTxK1jXwnFnCxkQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/hawaiian-aroma-caffe-the-ilikai-honolulu?adjust_creative=L6aEZ7VCBeYnaQEYoR4t_A&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=L6aEZ7VCBeYnaQEYoR4t_A',
#   'review_count': 320,
#   'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#    {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#    {'alias': 'acaibowls', 'title': 'Acai Bowls'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 21.284284973453296,
#    'longitude': -157.8387676731373},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$$',
#   'location': {'address1': '1777 Ala Moana Blvd',
#    'address2': '',
#    'address3': '',
#    'city': 'Honolulu',
#    'zip_code': '96815',
#    'country': 'US',
#    'state': 'HI',
#    'display_address': ['1777 Ala Moana Blvd', 'Honolulu, HI 96815']},
#   'phone': '+18082562602',
#   'display_phone': '(808) 256-2602',
#   'distance': 1442.3297250589599}]

# %%
results['total']
# Out:
# 94

# %%
results['region']
# Out:
# {'center': {'longitude': -157.82873153686523, 'latitude': 21.275296393424053}}

# %%
## How many results total?
pd.DataFrame(results['businesses'])
# Out:
#                         id                                     alias  \
# 0   AVSOYqrPYsLo7c-XRDwobg                the-sunrise-shack-honolulu
# 1   3vsRGQGSVPec7kKBFGhowA                alo-cafe-hawaii-honolulu-2
# 2   QMPFWhM_kMIMSSBQf48-Gg                 waffle-and-berry-honolulu
# 3   FhShWwhWNm4j6yMjyF0MCw        banán-waikiki-beach-shack-honolulu
# 4   vZ6iGKsU7zX8MT5rwNJeZw                   tropical-tribe-honolulu
# 5   vFz6Nwo0LgpbJcU9St-uPA    da-cove-health-bar-and-cafe-honolulu-4
# 6   kg9DW8QwQ6NEorFdUSUhgA   nalu-health-bar-and-cafe-urban-honolulu
# 7   iGIjmLHJAiwUP-oHpWP-Sw       aloh-health-bar-and-cafe-honolulu-2
# 8   oqnyvvSvWSNICv4QhzHyQg       island-vintage-shave-ice-honolulu-7
# 9   tUDgSvk3bdNV_UJJ-yf7XQ              aloha-bowls-and-tea-honolulu
# 10  n5oK86I5tdZCBSR5vxw38A  hawaiian-aroma-caffe-ohana-east-honolulu
# 11  wX8nkQf0zGfYI6LaIuYqvQ                 tropical-tribe-honolulu-4
# 12  GRvf-c-_ALRvhzXIvgD_tA               tucker-and-bevvy-honolulu-5
# 13  xNRyrUw1-6OyVQ44wKV-Og                  coffee-shop-831-honolulu
# 14  RiwA77HKyZW1geZh2BJtgQ  big-wave-dave-surf-and-coffee-honolulu-7
# 15  lSuf6g0V6MmFe69ZxRRTrA                  kai-fresh-urban-honolulu
# 16  3ZK5K9oMS5CTHBni0G9ieA              the-sunrise-shack-honolulu-2
# 17  n4hw4xPYXfcItEQD57UevA               tucker-and-bevvy-honolulu-4
# 18  c5AkizffmwCSfUo2gd5Hxg             hiking-hawaii-cafe-honolulu-3
# 19  w7z7ucVr_XOCLyK-zgb9bQ  hawaiian-aroma-caffe-the-ilikai-honolulu
#
#                                  name  \
# 0                   The Sunrise Shack
# 1                     ALO Cafe Hawaii
# 2                    Waffle and Berry
# 3         Banán - Waikiki Beach Shack
# 4                      Tropical Tribe
# 5           Da Cove Health Bar & Cafe
# 6              Nalu Health Bar & Cafe
# 7              Aloh Health Bar & Cafe
# 8            Island Vintage Shave Ice
# 9                 Aloha Bowls and Tea
# 10  Hawaiian Aroma Caffe - Ohana East
# 11                     Tropical Tribe
# 12                     Tucker & Bevvy
# 13                    Coffee Shop 831
# 14        Big Wave Dave Surf & Coffee
# 15                          Kai Fresh
# 16                  The Sunrise Shack
# 17                     Tucker & Bevvy
# 18                 Hiking Hawaii Cafe
# 19  Hawaiian Aroma Caffe - The Ilikai
#
#                                             image_url  is_closed  \
# 0   https://s3-media2.fl.yelpcdn.com/bphoto/kGVUny...      False
# 1   https://s3-media2.fl.yelpcdn.com/bphoto/_tn-bh...      False
# 2   https://s3-media4.fl.yelpcdn.com/bphoto/6VpIBT...      False
# 3   https://s3-media3.fl.yelpcdn.com/bphoto/HBcgiP...      False
# 4   https://s3-media3.fl.yelpcdn.com/bphoto/e7Y1Qu...      False
# 5   https://s3-media3.fl.yelpcdn.com/bphoto/aNlP2w...      False
# 6   https://s3-media2.fl.yelpcdn.com/bphoto/tn-UW0...      False
# 7   https://s3-media2.fl.yelpcdn.com/bphoto/KuUnIW...      False
# 8   https://s3-media3.fl.yelpcdn.com/bphoto/3frxsX...      False
# 9   https://s3-media3.fl.yelpcdn.com/bphoto/e_k8Bm...      False
# 10  https://s3-media4.fl.yelpcdn.com/bphoto/V4cb0r...      False
# 11  https://s3-media3.fl.yelpcdn.com/bphoto/G75exr...      False
# 12  https://s3-media2.fl.yelpcdn.com/bphoto/3u6koC...      False
# 13  https://s3-media2.fl.yelpcdn.com/bphoto/OCl2Mn...      False
# 14  https://s3-media4.fl.yelpcdn.com/bphoto/8AS_Bz...      False
# 15  https://s3-media3.fl.yelpcdn.com/bphoto/7ToiVa...      False
# 16  https://s3-media2.fl.yelpcdn.com/bphoto/BEG9Ty...      False
# 17  https://s3-media1.fl.yelpcdn.com/bphoto/3oBQVw...      False
# 18  https://s3-media3.fl.yelpcdn.com/bphoto/1GOFwq...      False
# 19  https://s3-media2.fl.yelpcdn.com/bphoto/OwnLS9...      False
#
#                                                   url  review_count  \
# 0   https://www.yelp.com/biz/the-sunrise-shack-hon...           784
# 1   https://www.yelp.com/biz/alo-cafe-hawaii-honol...            98
# 2   https://www.yelp.com/biz/waffle-and-berry-hono...           675
# 3   https://www.yelp.com/biz/ban%C3%A1n-waikiki-be...           518
# 4   https://www.yelp.com/biz/tropical-tribe-honolu...           592
# 5   https://www.yelp.com/biz/da-cove-health-bar-an...          1295
# 6   https://www.yelp.com/biz/nalu-health-bar-and-c...            10
# 7   https://www.yelp.com/biz/aloh-health-bar-and-c...            82
# 8   https://www.yelp.com/biz/island-vintage-shave-...            99
# 9   https://www.yelp.com/biz/aloha-bowls-and-tea-h...            48
# 10  https://www.yelp.com/biz/hawaiian-aroma-caffe-...           281
# 11  https://www.yelp.com/biz/tropical-tribe-honolu...            27
# 12  https://www.yelp.com/biz/tucker-and-bevvy-hono...           575
# 13  https://www.yelp.com/biz/coffee-shop-831-honol...           352
# 14  https://www.yelp.com/biz/big-wave-dave-surf-an...           169
# 15  https://www.yelp.com/biz/kai-fresh-urban-honol...            41
# 16  https://www.yelp.com/biz/the-sunrise-shack-hon...            75
# 17  https://www.yelp.com/biz/tucker-and-bevvy-hono...            76
# 18  https://www.yelp.com/biz/hiking-hawaii-cafe-ho...           849
# 19  https://www.yelp.com/biz/hawaiian-aroma-caffe-...           320
#
#                                            categories  rating  \
# 0   [{'alias': 'coffee', 'title': 'Coffee & Tea'},...     4.5
# 1   [{'alias': 'juicebars', 'title': 'Juice Bars &...     4.5
# 2   [{'alias': 'waffles', 'title': 'Waffles'}, {'a...     5.0
# 3   [{'alias': 'vegan', 'title': 'Vegan'}, {'alias...     4.5
# 4   [{'alias': 'acaibowls', 'title': 'Acai Bowls'}...     4.5
# 5   [{'alias': 'juicebars', 'title': 'Juice Bars &...     4.0
# 6   [{'alias': 'juicebars', 'title': 'Juice Bars &...     4.5
# 7   [{'alias': 'coffee', 'title': 'Coffee & Tea'},...     4.5
# 8   [{'alias': 'shavedice', 'title': 'Shaved Ice'}...     4.0
# 9   [{'alias': 'acaibowls', 'title': 'Acai Bowls'}...     4.5
# 10  [{'alias': 'breakfast_brunch', 'title': 'Break...     4.5
# 11  [{'alias': 'acaibowls', 'title': 'Acai Bowls'}...     5.0
# 12  [{'alias': 'breakfast_brunch', 'title': 'Break...     4.0
# 13  [{'alias': 'coffee', 'title': 'Coffee & Tea'},...     4.5
# 14  [{'alias': 'coffee', 'title': 'Coffee & Tea'},...     4.5
# 15  [{'alias': 'coffee', 'title': 'Coffee & Tea'},...     4.5
# 16  [{'alias': 'juicebars', 'title': 'Juice Bars &...     4.5
# 17  [{'alias': 'juicebars', 'title': 'Juice Bars &...     4.0
# 18  [{'alias': 'cafes', 'title': 'Cafes'}, {'alias...     4.5
# 19  [{'alias': 'coffee', 'title': 'Coffee & Tea'},...     4.0
#
#                                           coordinates        transactions  \
# 0   {'latitude': 21.277213128719804, 'longitude': ...          [delivery]
# 1     {'latitude': 21.27713, 'longitude': -157.82433}  [pickup, delivery]
# 2     {'latitude': 21.28594, 'longitude': -157.83275}  [pickup, delivery]
# 3   {'latitude': 21.2772821247839, 'longitude': -1...                  []
# 4   {'latitude': 21.28557897099554, 'longitude': -...  [pickup, delivery]
# 5   {'latitude': 21.26878, 'longitude': -157.8136199}  [pickup, delivery]
# 6   {'latitude': 21.279401, 'longitude': -157.831178}                  []
# 7   {'latitude': 21.280353794831946, 'longitude': ...  [pickup, delivery]
# 8   {'latitude': 21.272783224863293, 'longitude': ...                  []
# 9   {'latitude': 21.28298862765927, 'longitude': -...                  []
# 10  {'latitude': 21.27771853881159, 'longitude': -...          [delivery]
# 11  {'latitude': 21.278066211341383, 'longitude': ...                  []
# 12  {'latitude': 21.27176916049238, 'longitude': -...          [delivery]
# 13  {'latitude': 21.2793199, 'longitude': -157.82505}          [delivery]
# 14  {'latitude': 21.278767, 'longitude': -157.831514}          [delivery]
# 15    {'latitude': 21.27743, 'longitude': -157.82579}                  []
# 16    {'latitude': 21.29053, 'longitude': -157.84358}                  []
# 17  {'latitude': 21.2761299, 'longitude': -157.82543}          [delivery]
# 18    {'latitude': 21.28601, 'longitude': -157.83429}  [pickup, delivery]
# 19  {'latitude': 21.284284973453296, 'longitude': ...  [pickup, delivery]
#
#    price                                           location         phone  \
# 0     $$  {'address1': '2335 Kalakaua Ave', 'address2': ...  +18089266460
# 1     $$  {'address1': '159 Kaiulani Ave', 'address2': '...  +18087797887
# 2     $$  {'address1': '1958 Kalakaua Ave', 'address2': ...  +18082068272
# 3      $  {'address1': '2301 Kalakaua Ave', 'address2': ...  +18082001640
# 4     $$  {'address1': '1778 Ala Moana Blvd', 'address2'...  +18083668226
# 5     $$  {'address1': '3045 Monsarrat Ave', 'address2':...  +18087328744
# 6    NaN  {'address1': '226 Lewers St', 'address2': None...  +18084254710
# 7     $$  {'address1': '407 Seaside Ave', 'address2': No...  +18085488116
# 8     $$  {'address1': '2552 Kalakaua Ave', 'address2': ...
# 9     $$  {'address1': '2005 Kalia Rd', 'address2': '', ...  +18088077733
# 10    $$  {'address1': '150 Kaiulani Ave', 'address2': N...  +18082562602
# 11   NaN  {'address1': '2161 Kalia rd.', 'address2': 'St...  +18087447079
# 12    $$  {'address1': '2586 Kalakaua Ave', 'address2': ...  +18089220099
# 13    $$  {'address1': '411 Nahua St', 'address2': '', '...  +18088539888
# 14   NaN  {'address1': '226 Lewers St', 'address2': 'Ste...  +18083864872
# 15    $$  {'address1': '120 Kaiulani Ave', 'address2': N...
# 16   NaN  {'address1': '1450 Ala Moana Blvd', 'address2'...  +18082072604
# 17   NaN  {'address1': '2424 Kalakaua Ave', 'address2': ...  +18089222088
# 18    $$  {'address1': '1956 Ala Moana Blvd', 'address2'...  +18084451717
# 19    $$  {'address1': '1777 Ala Moana Blvd', 'address2'...  +18082562602
#
#      display_phone     distance
# 0   (808) 926-6460   243.572526
# 1   (808) 779-7887   505.744094
# 2   (808) 206-8272  1256.061740
# 3   (808) 200-1640   242.294662
# 4   (808) 366-8226  1522.472981
# 5   (808) 732-8744  1718.002818
# 6   (808) 425-4710   530.177160
# 7   (808) 548-8116   601.092447
# 8                    657.645350
# 9   (808) 807-7733  1148.326573
# 10  (808) 256-2602   489.233897
# 11  (808) 744-7079   581.559053
# 12  (808) 922-0099   764.776296
# 13  (808) 853-9888   573.159312
# 14  (808) 386-4872   481.715208
# 15                   418.425883
# 16  (808) 207-2604  2288.268759
# 17  (808) 922-2088   360.602693
# 18  (808) 445-1717  1309.526870
# 19  (808) 256-2602  1442.329725

# %% [markdown]
# - Where is the actual data we want to save?

# %%
## How many did we get the details for?
results_per_page = len(results['businesses'])
results_per_page
# Out:
# 20

# %% [markdown]
# - Calculate how many pages of results needed to cover the total_results

# %%
(results['total'])/ results_per_page
# Out:
# 4.7

# %%
# Use math.ceil to round up for the total number of pages of results.
n_pages = math.ceil((results['total'])/ results_per_page)
n_pages
# Out:
# 5

# %%
for i in tqdm_notebook(range(1,n_pages+1)):
    ## The block of code we want to TRY to run
    try:
        
        time.sleep(.2)
        
        ## Read in results in progress file and check the length
        with open(JSON_FILE, 'r') as f:
            previous_results = json.load(f)
        
        ## save number of results to use as offset
        n_results = len(previous_results)
        
        
        ## use n_results as the OFFSET 
        results = yelp.search_query(location = location, term = term,
                                   offset = n_results+1)

        ## append new results and save to file
        previous_results.extend(results['businesses'])
        
        with open(JSON_FILE, 'w') as f:
            json.dump(previous_results, f)


            
    ## What to do if we get an error/exception.
    except Exception as e:
        print(' [!] ERROR', e)
# Out:
#   0%|          | 0/5 [00:00<?, ?it/s]

# %% [markdown]
# ## Open the Final JSON File with Pandas

# %%
df = pd.read_json(JSON_FILE)

# %%
df.head()
# Out:
#                        id                                   alias  \
# 0  3vsRGQGSVPec7kKBFGhowA              alo-cafe-hawaii-honolulu-2
# 1  QMPFWhM_kMIMSSBQf48-Gg               waffle-and-berry-honolulu
# 2  FhShWwhWNm4j6yMjyF0MCw      banán-waikiki-beach-shack-honolulu
# 3  vZ6iGKsU7zX8MT5rwNJeZw                 tropical-tribe-honolulu
# 4  vFz6Nwo0LgpbJcU9St-uPA  da-cove-health-bar-and-cafe-honolulu-4
#
#                           name  \
# 0              ALO Cafe Hawaii
# 1             Waffle and Berry
# 2  Banán - Waikiki Beach Shack
# 3               Tropical Tribe
# 4    Da Cove Health Bar & Cafe
#
#                                            image_url  is_closed  \
# 0  https://s3-media2.fl.yelpcdn.com/bphoto/_tn-bh...      False
# 1  https://s3-media4.fl.yelpcdn.com/bphoto/6VpIBT...      False
# 2  https://s3-media3.fl.yelpcdn.com/bphoto/HBcgiP...      False
# 3  https://s3-media3.fl.yelpcdn.com/bphoto/e7Y1Qu...      False
# 4  https://s3-media3.fl.yelpcdn.com/bphoto/aNlP2w...      False
#
#                                                  url  review_count  \
# 0  https://www.yelp.com/biz/alo-cafe-hawaii-honol...            98
# 1  https://www.yelp.com/biz/waffle-and-berry-hono...           675
# 2  https://www.yelp.com/biz/ban%C3%A1n-waikiki-be...           518
# 3  https://www.yelp.com/biz/tropical-tribe-honolu...           592
# 4  https://www.yelp.com/biz/da-cove-health-bar-an...          1295
#
#                                           categories  rating  \
# 0  [{'alias': 'juicebars', 'title': 'Juice Bars &...     4.5
# 1  [{'alias': 'waffles', 'title': 'Waffles'}, {'a...     5.0
# 2  [{'alias': 'vegan', 'title': 'Vegan'}, {'alias...     4.5
# 3  [{'alias': 'acaibowls', 'title': 'Acai Bowls'}...     4.5
# 4  [{'alias': 'juicebars', 'title': 'Juice Bars &...     4.0
#
#                                          coordinates        transactions  \
# 0    {'latitude': 21.27713, 'longitude': -157.82433}  [delivery, pickup]
# 1    {'latitude': 21.28594, 'longitude': -157.83275}  [delivery, pickup]
# 2  {'latitude': 21.2772821247839, 'longitude': -1...                  []
# 3  {'latitude': 21.28557897099554, 'longitude': -...  [delivery, pickup]
# 4  {'latitude': 21.26878, 'longitude': -157.8136199}  [delivery, pickup]
#
#   price                                           location         phone  \
# 0    $$  {'address1': '159 Kaiulani Ave', 'address2': '...  +18087797887
# 1    $$  {'address1': '1958 Kalakaua Ave', 'address2': ...  +18082068272
# 2     $  {'address1': '2301 Kalakaua Ave', 'address2': ...  +18082001640
# 3    $$  {'address1': '1778 Ala Moana Blvd', 'address2'...  +18083668226
# 4    $$  {'address1': '3045 Monsarrat Ave', 'address2':...  +18087328744
#
#     display_phone     distance
# 0  (808) 779-7887   505.744094
# 1  (808) 206-8272  1256.061740
# 2  (808) 200-1640   242.294662
# 3  (808) 366-8226  1522.472981
# 4  (808) 732-8744  1718.002818

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 91 entries, 0 to 90
# Data columns (total 16 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             91 non-null     object
#  1   alias          91 non-null     object
#  2   name           91 non-null     object
#  3   image_url      91 non-null     object
#  4   is_closed      91 non-null     bool
#  5   url            91 non-null     object
#  6   review_count   91 non-null     int64
#  7   categories     91 non-null     object
#  8   rating         91 non-null     float64
#  9   coordinates    91 non-null     object
#  10  transactions   91 non-null     object
#  11  price          68 non-null     object
#  12  location       91 non-null     object
#  13  phone          91 non-null     object
#  14  display_phone  91 non-null     object
#  15  distance       91 non-null     float64
# dtypes: bool(1), float64(2), int64(1), object(12)
# memory usage: 10.9+ KB

# %%
## convert the filename to a .csv.gz
csv_file = JSON_FILE.replace('.json','.csv.gz')
csv_file
# Out:
# 'Data/Waikiki-acai.csv.gz'

# %%
## convert the filename to a .csv.gz

# %%
## Save it as a compressed csv (to save space)
df.to_csv(csv_file, compression = 'gzip', index = False)

# %% [markdown]
# ## Bonus: compare filesize with os module's `os.path.getsize`

# %%
size_json = os.path.getsize(JSON_FILE)
size_csv_gz = os.path.getsize(JSON_FILE.replace('.json','.csv.gz'))

print(f'JSON FILE: {size_json:,} Bytes')
print(f'CSV.GZ FILE: {size_csv_gz:,} Bytes')

print(f'the csv.gz is {size_json/size_csv_gz} times smaller!')
# Out:
# JSON FILE: 92,598 Bytes
# CSV.GZ FILE: 13,000 Bytes
# the csv.gz is 7.122923076923077 times smaller!

# %% [markdown]
# ## Next Class: Processing the Results and Mapping
